# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install spotipy

# %%
import os
import random
import pandas as pd
from spotipy import Spotify
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Spotify Setup ---
SPOTIFY_CLIENT_ID = os.getenv('SPOTIFY CLIENT ID')
SPOTIFY_CLIENT_SECRET = os.getenv('SPOTIFY CLIENT SECRET')

if SPOTIFY_CLIENT_ID and SPOTIFY_CLIENT_SECRET :
    sp = Spotify (auth_manager = SpotifyClientCredentials(
        client_id = SPOTIFY_CLIENT_ID,
        client_secret = SPOTIFY_CLIENT_SECRET
    ))
else :
    sp = None #Fallback mode

# %%
#Load CSV Fallback ---
import os
print(os.path.exists("../datasets/moodylyrics_sample.csv"))

df = pd.read_csv("../datasets/moodylyrics_sample.csv")
# Out:
# True

# %%
#Mood Mapping Logic ---
def map_song_by_mood (mood:string) :
    mood = mood(lower)

    if sp :
        #Live Spotify Query
        search_query = 'happy' if mood == 'happy' else 'sad'
        results = sp.search(q=search_query, type = 'track',limit=5)
        if results['tracks']['items'] :
            choice = random.choice(results['tracks']['items'])
            audio = sp.audio_features(choice['id'])[0]
            return {
                'track' : choice['name'],
                'artist' : choice['artists'][0]['name'],
                'valence' : audio['valence'],
                'energy' : audio['energy'],
                'preview' : choice['preview_url']
            }
